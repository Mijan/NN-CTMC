# %%
import sys
from pathlib import Path
import numpy as np
import csv
import matplotlib.pyplot as plt
import pandas as pd
sys.path.insert(0, "/home/jan/crypt/Dropbox/LFNS/scripts/python")

# %%
import LFNS_aux_scripts as lfns

# %%
sim_folder = Path("/home/jan/crypt/Dropbox/Makarere/Projects/NN_for_CTMC/test_models/Lotka_Voltera/results")
sim_file_name = "sims_model_summary.txt"
lfns.plot_system(str(sim_folder / sim_file_name))

# %%
sim_folder = Path("/home/jan/crypt/Dropbox/Makarere/Projects/NN_for_CTMC/test_models/CRN_model/results")
sim_file_name = "sims_model_summary.txt"
lfns.plot_system(str(sim_folder / sim_file_name))

# %%
sim_folder = Path("/home/jan/crypt/Dropbox/Makarere/Projects/NN_for_CTMC/test_models/birth_death/results")
sim_file_name = "sims_model_summary.txt"
lfns.plot_system(str(sim_folder / sim_file_name))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 sim_folder = Path("/home/jan/crypt/Dropbox/Makarere/Projects/NN_for_CTMC/test_models/birth_death/results")
#       2 sim_file_name = "sims_model_summary.txt"
# ----> 3 lfns.plot_system(str(sim_folder / sim_file_name))
#
# File ~/crypt/Dropbox/LFNS/scripts/python/LFNS_aux_scripts.py:269, in plot_system(summary_file_name, data_file_names, time_file_names, num_measures)
#     267 plt.subplot(num_rows, num_cols, i+1)
#     268 if num_states > 1:
# --> 269     [plt.plot(t, latent_states[(num_states *row) + i::num_states *row+1 , :][0], linewidth=2) for row in range(num_simulations) ]
#     270 else:
#     271     [plt.plot(t, latent_states[(num_states * row) + i::num_states * row + 1, :][0], linewidth=2) for row in
#     272      range(num_simulations)]
#
# ...
